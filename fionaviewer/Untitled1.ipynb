# %% [markdown]
# import pyqtgraph.examples
# pyqtgraph.examples.run()

# %%
import pyqtgraph as pg

# %%
# %run __main__.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/john/Documents/Coding/Python/pyfionaviewer/fionaviewer/plotter.py in mouseMoved(self, evt)
#      51             mousePoint = self.vb.mapSceneToView(pos)
#      52             index = int(mousePoint.x())
# ---> 53             if index > 0 and index < len(data1):
#      54                 label.setText("<span style='font-size: 12pt'>x=%0.1f,   <span style='color: red'>y1=%0.1f</span>,...   <span style='color: green'>y2=%0.1f</span>" % (mousePoint.x(), data1[index], data2[index]))
#      55                 self.vLine.setPos(mousePoint.x())
#
# NameError: name 'data1' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ...
